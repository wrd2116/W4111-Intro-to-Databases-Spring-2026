# %%
# %pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-6.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pytz (from neo4j)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Downloading neo4j-6.1.0-py3-none-any.whl (325 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz, neo4j
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [neo4j]━━━━━ 1/2 [neo4j]
# Successfully installed neo4j-6.1.0 pytz-2026.1.post1
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
NEO4J_URI="neo4j+ssc://15ed6c28.databases.neo4j.io"
NEO4J_USERNAME="15ed6c28"
NEO4J_PASSWORD="IllFSBhDximX2vVRGWTjeeADZIBWAmiWKKZuW94ZvRs"
NEO4J_DATABASE="15ed6c28"
AURA_INSTANCEID="15ed6c28"
AURA_INSTANCENAME="Instance02"

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"

URL = NEO4J_URI

AUTH = (NEO4J_USERNAME, NEO4J_PASSWORD)



with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"

URL = NEO4J_URI

AUTH = (NEO4J_USERNAME, NEO4J_PASSWORD)



with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

    records, summary, keys = driver.execute_query("""
    MATCH (p:Person)-[:FOLLOWS]->(:Person)
    RETURN p.name AS name
    """,
    database_=NEO4J_DATABASE,
)

# Loop through results and do something with them
for record in records:
    print(record.data())  # obtain record as dict

# Summary information
print("The query `{query}` returned {records_count} records in {time} ms.".format(
    query=summary.query, records_count=len(records),
    time=summary.result_available_after
))
# Out:
# {'name': 'Paul Blythe'}
# {'name': 'Angela Scope'}
# {'name': 'James Thompson'}
# The query `
#     MATCH (p:Person)-[:FOLLOWS]->(:Person)
#     RETURN p.name AS name
#     ` returned 3 records in 18 ms.

# %%
with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

    records, summary, keys = driver.execute_query("""
        MATCH (p:Person {name: "Tom Hanks"})
        RETURN p
    """,
    database_=NEO4J_DATABASE,
)

# Loop through results and do something with them
for record in records:
    print(record.data())  # obtain record as dict

# Summary information
print("The query `{query}` returned {records_count} records in {time} ms.".format(
    query=summary.query, records_count=len(records),
    time=summary.result_available_after
))
# Out:
# {'p': {'born': 1956, 'name': 'Tom Hanks'}}
# The query `
#         MATCH (p:Person {name: "Tom Hanks"})
#         RETURN p
#     ` returned 1 records in 15 ms.

# %%
with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

    records, summary, keys = driver.execute_query("""
        MATCH (p:Person {name: "Tom Hanks"})-[r:DIRECTED]->(m)
        RETURN p,r,m
    """,
    database_=NEO4J_DATABASE,
)

# Loop through results and do something with them
for record in records:
    print(record.data())  # obtain record as dict

# Summary information
print("The query `{query}` returned {records_count} records in {time} ms.".format(
    query=summary.query, records_count=len(records),
    time=summary.result_available_after
))
# Out:
# {'p': {'born': 1956, 'name': 'Tom Hanks'}, 'r': ({'born': 1956, 'name': 'Tom Hanks'}, 'DIRECTED', {'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996}), 'm': {'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996}}
# The query `
#         MATCH (p:Person {name: "Tom Hanks"})-[r:DIRECTED]->(m)
#         RETURN p,r,m
#     ` returned 1 records in 22 ms.

# %%
records
# Out:
# [<Record p=<Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:68' labels=frozenset({'Person'}) properties={'born': 1956, 'name': 'Tom Hanks'}> r=<Relationship element_id='5:dd4da19a-ea8c-4280-b9fa-99492d0554c0:6917530127152709717' nodes=(<Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:68' labels=frozenset({'Person'}) properties={'born': 1956, 'name': 'Tom Hanks'}>, <Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:85' labels=frozenset({'Movie'}) properties={'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996}>) type='DIRECTED' properties={}> m=<Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:85' labels=frozenset({'Movie'}) properties={'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996}>>]

# %%
records[0]
# Out:
# <Record p=<Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:68' labels=frozenset({'Person'}) properties={'born': 1956, 'name': 'Tom Hanks'}> r=<Relationship element_id='5:dd4da19a-ea8c-4280-b9fa-99492d0554c0:6917530127152709717' nodes=(<Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:68' labels=frozenset({'Person'}) properties={'born': 1956, 'name': 'Tom Hanks'}>, <Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:85' labels=frozenset({'Movie'}) properties={'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996}>) type='DIRECTED' properties={}> m=<Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:85' labels=frozenset({'Movie'}) properties={'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996}>>

# %%
type(records[0])
# Out:
# neo4j._data.Record

# %%
dir(records[0])
# Out:
# ['_Record__keys',
#  '__abstractmethods__',
#  '__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '_abc_impl',
#  '_broken_record_error',
#  '_super_getitem_single',
#  'count',
#  'data',
#  'get',
#  'index',
#  'items',
#  'keys',
#  'value',
#  'values']

# %%
records[0].data()
# Out:
# {'p': {'born': 1956, 'name': 'Tom Hanks'},
#  'r': ({'born': 1956, 'name': 'Tom Hanks'},
#   'DIRECTED',
#   {'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do',
#    'title': 'That Thing You Do',
#    'released': 1996}),
#  'm': {'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do',
#   'title': 'That Thing You Do',
#   'released': 1996}}

# %%
type(records[0].data())
# Out:
# dict

# %%
r=records[0]

# %%
r.keys()
# Out:
# ['p', 'r', 'm']

# %%
r['p']
# Out:
# <Node element_id='4:dd4da19a-ea8c-4280-b9fa-99492d0554c0:68' labels=frozenset({'Person'}) properties={'born': 1956, 'name': 'Tom Hanks'}>

# %%
dir(r['p'])
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_element_id',
#  '_graph',
#  '_id',
#  '_labels',
#  '_properties',
#  'element_id',
#  'get',
#  'graph',
#  'id',
#  'items',
#  'keys',
#  'labels',
#  'values']

# %%
list(r['p'].labels)
# Out:
# ['Person']

# %%
with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

    records, summary, keys = driver.execute_query("""
        MATCH (p:Person {name: "Tom Hanks"})-[r:DIRECTED]->(m)<-[:ACTED_IN]-(p2)
        RETURN m.title, p2.name
    """,
    database_=NEO4J_DATABASE,
)

# Loop through results and do something with them
for record in records:
    print(record.data())  # obtain record as dict

# Summary information
print("The query `{query}` returned {records_count} records in {time} ms.".format(
    query=summary.query, records_count=len(records),
    time=summary.result_available_after
))
# Out:
# {'m.title': 'That Thing You Do', 'p2.name': 'Charlize Theron'}
# {'m.title': 'That Thing You Do', 'p2.name': 'Tom Hanks'}
# {'m.title': 'That Thing You Do', 'p2.name': 'Liv Tyler'}
# The query `
#         MATCH (p:Person {name: "Tom Hanks"})-[r:DIRECTED]->(m)<-[:ACTED_IN]-(p2)
#         RETURN m.title, p2.name
#     ` returned 3 records in 25 ms.

# %%
with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

    records, summary, keys = driver.execute_query("""
        MATCH (p:Person {name: "Tom Hanks"})-[r:ACTED_IN]->(m)<-[:ACTED_IN]-(p2)
        RETURN m.title, p2.name
    """,
    database_=NEO4J_DATABASE,
)

# Loop through results and do something with them
for record in records:
    print(record.data())  # obtain record as dict

# Summary information
print("The query `{query}` returned {records_count} records in {time} ms.".format(
    query=summary.query, records_count=len(records),
    time=summary.result_available_after
))
# Out:
# {'m.title': "You've Got Mail", 'p2.name': 'Meg Ryan'}
# {'m.title': "You've Got Mail", 'p2.name': 'Greg Kinnear'}
# {'m.title': "You've Got Mail", 'p2.name': 'Parker Posey'}
# {'m.title': "You've Got Mail", 'p2.name': 'Dave Chappelle'}
# {'m.title': "You've Got Mail", 'p2.name': 'Steve Zahn'}
# {'m.title': 'Sleepless in Seattle', 'p2.name': 'Meg Ryan'}
# {'m.title': 'Sleepless in Seattle', 'p2.name': 'Rita Wilson'}
# {'m.title': 'Sleepless in Seattle', 'p2.name': 'Bill Pullman'}
# {'m.title': 'Sleepless in Seattle', 'p2.name': 'Victor Garber'}
# {'m.title': 'Sleepless in Seattle', 'p2.name': "Rosie O'Donnell"}
# {'m.title': 'Joe Versus the Volcano', 'p2.name': 'Meg Ryan'}
# {'m.title': 'Joe Versus the Volcano', 'p2.name': 'Nathan Lane'}
# {'m.title': 'That Thing You Do', 'p2.name': 'Charlize Theron'}
# {'m.title': 'That Thing You Do', 'p2.name': 'Liv Tyler'}
# {'m.title': 'Cloud Atlas', 'p2.name': 'Hugo Weaving'}
# {'m.title': 'Cloud Atlas', 'p2.name': 'Halle Berry'}
# {'m.title': 'Cloud Atlas', 'p2.name': 'Jim Broadbent'}
# {'m.title': 'The Da Vinci Code', 'p2.name': 'Ian McKellen'}
# {'m.title': 'The Da Vinci Code', 'p2.name': 'Audrey Tautou'}
# {'m.title': 'The Da Vinci Code', 'p2.name': 'Paul Bettany'}
# {'m.title': 'The Green Mile', 'p2.name': 'Bonnie Hunt'}
# {'m.title': 'The Green Mile', 'p2.name': 'James Cromwell'}
# {'m.title': 'The Green Mile', 'p2.name': 'Michael Clarke Duncan'}
# {'m.title': 'The Green Mile', 'p2.name': 'David Morse'}
# {'m.title': 'The Green Mile', 'p2.name': 'Sam Rockwell'}
# {'m.title': 'The Green Mile', 'p2.name': 'Gary Sinise'}
# {'m.title': 'The Green Mile', 'p2.name': 'Patricia Clarkson'}
# {'m.title': 'Apollo 13', 'p2.name': 'Kevin Bacon'}
# {'m.title': 'Apollo 13', 'p2.name': 'Gary Sinise'}
# {'m.title': 'Apollo 13', 'p2.name': 'Ed Harris'}
# {'m.title': 'Apollo 13', 'p2.name': 'Bill Paxton'}
# {'m.title': 'Cast Away', 'p2.name': 'Helen Hunt'}
# {'m.title': "Charlie Wilson's War", 'p2.name': 'Philip Seymour Hoffman'}
# {'m.title': "Charlie Wilson's War", 'p2.name': 'Julia Roberts'}
# {'m.title': 'A League of Their Own', 'p2.name': "Rosie O'Donnell"}
# {'m.title': 'A League of Their Own', 'p2.name': 'Bill Paxton'}
# {'m.title': 'A League of Their Own', 'p2.name': 'Madonna'}
# {'m.title': 'A League of Their Own', 'p2.name': 'Geena Davis'}
# {'m.title': 'A League of Their Own', 'p2.name': 'Lori Petty'}
# The query `
#         MATCH (p:Person {name: "Tom Hanks"})-[r:ACTED_IN]->(m)<-[:ACTED_IN]-(p2)
#         RETURN m.title, p2.name
#     ` returned 39 records in 25 ms.
