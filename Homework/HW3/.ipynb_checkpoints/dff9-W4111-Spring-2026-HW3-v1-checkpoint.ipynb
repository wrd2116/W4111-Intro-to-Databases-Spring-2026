# %% [markdown]
# <span style="font-size:36pt">dff9-W4111-Spring-2026
# -HW3.ipynb<span>

# %% [markdown]
# # Introduction

# %% [markdown]
# __This is in-progress. Please do not start the homework.__

# %% [markdown]
# ## Homework Overview

# %% [markdown]
# There is one version of the homework that both the programming and non-programming tracks complete.
#
# There are 3 categories of question:
# 1. Short answer questions testing general knowledge and the ability to reason about the course material.<br><br>
# 2. SQL questions testing the ability to use SQL to produce data results from descriptions of the desired output.<br><br>
# 3. Short questions testing the ability to use MongoDB and Neo4j to produce results from descriptions of the desired output.<br><br>

# %% [markdown]
# ## Submission Instructions

# %% [markdown]
# The homework is due at 11:59 PM on Sunday, 12-April-2026.
#
# Please see [Ed discussion](https://edstem.org/us/courses/94820/discussion/7865497) for detailed submission instructions and for clarifications and answering questions.

# %% [markdown]
# # Part 1 $-$ Setup

# %% [markdown]
# ## iPython-SQL

# %%
# %load_ext sql

# %% [markdown]
# Set the proper root user ID and password for MySQL in the python cell below.

# %%
mysql_root_user = 'root'
mysql_root_password = 'dbuserdbuser'

mysql_url = f"mysql+pymysql://{mysql_root_user}:{mysql_root_password}@localhost"

# %%
mysql_url
# Out:
# 'mysql+pymysql://root:dbuserdbuser@localhost'

# %%
# %sql $mysql_url
# Out:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sql/connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#         connect_str, connect_args=connect_args
#     )
#   File "<string>", line 2, in create_engine
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/util/deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/create.py", line 617, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/dialects/mysql/pymysql.py", line 89, in import_dbapi
#     return __import__("pymysql")
# ModuleNotFoundError: No module named 'pymysql'
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sql/magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#         connect_str,
#     ...<2 lines>...
#         creator=args.creator,
#     )
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sql/connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#                               ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sql/connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#         connect_str, connect_args=connect_args
#     )
#   File "<string>", line 2, in create_engine
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/util/deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/create.py", line 617, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/dialects/mysql/pymysql.py", line 89, in import_dbapi
#     return __import__("pymysql")
# ModuleNotFoundError: No module named 'pymysql'
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %sql select * from db_book.student where dept_name="Comp. Sci."
# Out:
#  * mysql+pymysql://root:***@localhost
# 4 rows affected.
# [('00128', 'Zhang', 'Comp. Sci.', Decimal('102')),
#  ('12345', 'Shankar', 'Comp. Sci.', Decimal('32')),
#  ('54321', 'Williams', 'Comp. Sci.', Decimal('54')),
#  ('76543', 'Brown', 'Comp. Sci.', Decimal('58'))]

# %% [markdown]
# ## SQL Alchemy

# %%
from sqlalchemy import create_engine, text

# %%
engine = create_engine(mysql_url)

# %%
# Raw SQL query
sql = text("SELECT * FROM db_book.student WHERE dept_name = :dept")

# Execute query
with engine.connect() as connection:
    result = connection.execute(sql, {"dept": "Comp. Sci."})
    
    for row in result:
        print(row)
# Out:
# ('00128', 'Zhang', 'Comp. Sci.', Decimal('102'))
# ('12345', 'Shankar', 'Comp. Sci.', Decimal('32'))
# ('54321', 'Williams', 'Comp. Sci.', Decimal('54'))
# ('76543', 'Brown', 'Comp. Sci.', Decimal('58'))

# %% [markdown]
# ## Pandas

# %%
import pandas

# %%
result = pandas.read_sql(con=engine, sql="select * from db_book.student where dept_name='Comp. Sci.'")

# %%
result
# Out:
#       ID      name   dept_name  tot_cred
# 0  00128     Zhang  Comp. Sci.     102.0
# 1  12345   Shankar  Comp. Sci.      32.0
# 2  54321  Williams  Comp. Sci.      54.0
# 3  76543     Brown  Comp. Sci.      58.0

# %% [markdown]
# ## PyMySQL

# %%
import pymysql

# %%
conn = pymysql.connect(
    host="localhost",
    user=mysql_root_user,
    password=mysql_root_password,
    cursorclass=pymysql.cursors.DictCursor,
    autocommit=True
)

# %%
cursor = conn.cursor()

# %%
result = cursor.execute("select * from db_book.student where dept_name='Comp. Sci.'")
result = cursor.fetchall()

# %%
result
# Out:
# [{'ID': '00128',
#   'name': 'Zhang',
#   'dept_name': 'Comp. Sci.',
#   'tot_cred': Decimal('102')},
#  {'ID': '12345',
#   'name': 'Shankar',
#   'dept_name': 'Comp. Sci.',
#   'tot_cred': Decimal('32')},
#  {'ID': '54321',
#   'name': 'Williams',
#   'dept_name': 'Comp. Sci.',
#   'tot_cred': Decimal('54')},
#  {'ID': '76543',
#   'name': 'Brown',
#   'dept_name': 'Comp. Sci.',
#   'tot_cred': Decimal('58')}]
